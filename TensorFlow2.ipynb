# %% [markdown]
# <a href="https://colab.research.google.com/github/nishtha911/tf_dl/blob/main/TensorFlow2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Neural Network Regression

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.19.0

# %%
import numpy as np
import matplotlib.pyplot as plt

X = np.array([-7.0, -4.0, -1.0, 2.0, 5.0, 8.0, 11.0, 14.0])
y = np.array([3.0, 6.0, 9.0, 12.0, 15.0, 18.0, 21.0, 24.0])

plt.scatter(X,y);

# %%
y == X + 10
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True])

# %%
house_info = tf.constant(["bedroom", "bathroom", "garage"])
house_price = tf.constant([939700])
house_info, house_price
# Out:
# (<tf.Tensor: shape=(3,), dtype=string, numpy=array([b'bedroom', b'bathroom', b'garage'], dtype=object)>,
#  <tf.Tensor: shape=(1,), dtype=int32, numpy=array([939700], dtype=int32)>)

# %%
input_shape = X[0].shape
output_shape = y[0].shape
input_shape, output_shape
# Out:
# ((), ())

# %%
tf.random.set_seed(42)

model = tf.keras.Sequential([
  tf.keras.layers.Dense(100, activation=None),
  tf.keras.layers.Dense(100, activation=None),
  tf.keras.layers.Dense(1)
])

model.compile(loss=tf.keras.losses.mae,
              optimizer=tf.keras.optimizers.SGD(),
              metrics=["mae"])

model.fit(tf.expand_dims(X, axis=-1), y, epochs=5)
# Out:
# Epoch 1/5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 594ms/step - loss: 14.1908 - mae: 14.1908
# Epoch 2/5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 13.2034 - mae: 13.2034
# Epoch 3/5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 12.2194 - mae: 12.2194
# Epoch 4/5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 11.2091 - mae: 11.2091
# Epoch 5/5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 10.1421 - mae: 10.1421

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Dense(100, activation=None),
  tf.keras.layers.Dense(100, activation=None),
  tf.keras.layers.Dense(1)
])

model.compile(loss=tf.keras.losses.mae,
              optimizer=tf.keras.optimizers.SGD(),
              metrics=["mae"])

model.fit(tf.expand_dims(X, axis=-1), y, epochs=100)
# Out:
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 457ms/step - loss: 14.4964 - mae: 14.4964
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 13.4334 - mae: 13.4334
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 12.3839 - mae: 12.3839
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 11.3150 - mae: 11.3150
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 10.1931 - mae: 10.1931
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 8.9820 - mae: 8.9820
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 7.6404 - mae: 7.6404
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 7.5770 - mae: 7.5770
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 7.3114 - mae: 7.3114
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 7.7427 - mae: 7.7427
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 7.1405 - mae: 7.1405
# Epoch 12/100
# ...

# %%
X, y
# Out:
# (array([-7., -4., -1.,  2.,  5.,  8., 11., 14.]),
#  array([ 3.,  6.,  9., 12., 15., 18., 21., 24.]))

# %%
model.predict(tf.expand_dims(tf.constant([17.0], dtype=tf.float32), axis=-1))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# array([[13.768068]], dtype=float32)

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Dense(100, activation="relu"),
  tf.keras.layers.Dense(1)
])

model.compile(loss=tf.keras.losses.mae,
              optimizer=tf.keras.optimizers.SGD(),
              metrics=["mae"])

model.fit(tf.expand_dims(X, axis=-1), y, epochs=100)
# Out:
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 412ms/step - loss: 14.4204 - mae: 14.4204
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 13.8319 - mae: 13.8319
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 13.2542 - mae: 13.2542
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 12.6819 - mae: 12.6819
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 12.1078 - mae: 12.1078
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 11.5242 - mae: 11.5242
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 10.9250 - mae: 10.9250
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 10.3070 - mae: 10.3070
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 9.6616 - mae: 9.6616
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 8.9842 - mae: 8.9842
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 8.2682 - mae: 8.2682
# Epoch 12/100
# ...

# %%
model.predict(tf.expand_dims(tf.constant([17.0], dtype=tf.float32), axis=-1))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# array([[31.907345]], dtype=float32)

# %%
X = tf.range(-100, 100, 4)
X
# Out:
# <tf.Tensor: shape=(50,), dtype=int32, numpy=
# array([-100,  -96,  -92,  -88,  -84,  -80,  -76,  -72,  -68,  -64,  -60,
#         -56,  -52,  -48,  -44,  -40,  -36,  -32,  -28,  -24,  -20,  -16,
#         -12,   -8,   -4,    0,    4,    8,   12,   16,   20,   24,   28,
#          32,   36,   40,   44,   48,   52,   56,   60,   64,   68,   72,
#          76,   80,   84,   88,   92,   96], dtype=int32)>

# %%
y = X + 10
y
# Out:
# <tf.Tensor: shape=(50,), dtype=int32, numpy=
# array([-90, -86, -82, -78, -74, -70, -66, -62, -58, -54, -50, -46, -42,
#        -38, -34, -30, -26, -22, -18, -14, -10,  -6,  -2,   2,   6,  10,
#         14,  18,  22,  26,  30,  34,  38,  42,  46,  50,  54,  58,  62,
#         66,  70,  74,  78,  82,  86,  90,  94,  98, 102, 106], dtype=int32)>

# %%
import matplotlib.pyplot as plt
plt.scatter(X, y);

# %% [markdown]
# len(X)m

# %%
X_train = X[:40]
y_train = y[:40]

X_test = X[40:]
y_test = y[40:]

len(X_train), len(X_test)
# Out:
# (40, 10)

# %%
plt.figure(figsize=(10, 7))
plt.scatter(X_train, y_train, c="b", label="Training data")
plt.scatter(X_test, y_test, c="g", label="Testing data")
plt.legend();

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Dense(1)
])

model.compile(loss=tf.keras.losses.mae,
              optimizer=tf.keras.optimizers.SGD(),
              metrics=["mae"])

model.fit(tf.expand_dims(X_train, axis=-1), y_train, epochs=100)
# Out:
# Epoch 1/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 8.3587 - mae: 8.3587
# Epoch 2/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 9.0673 - mae: 9.0673
# Epoch 3/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 8.0535 - mae: 8.0535
# Epoch 4/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 9.7634 - mae: 9.7634
# Epoch 5/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 8.0356 - mae: 8.0356
# Epoch 6/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 9.7518 - mae: 9.7518
# Epoch 7/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 8.0178 - mae: 8.0178
# Epoch 8/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 9.7402 - mae: 9.7402
# Epoch 9/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.9999 - mae: 7.9999
# Epoch 10/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 9.7286 - mae: 9.7286
# Epoch 11/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 8.1081 - mae: 8.1081
# Epoch 12/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.6523 - mae: 8.6523
# ...

# %%
tf.random.set_seed(42)

model.build(input_shape=(1,))
